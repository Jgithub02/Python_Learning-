# %% [markdown]
# <a href="https://colab.research.google.com/github/Jgithub02/Python_Learning-/blob/main/Session1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Python is a case sensitive language

# %%
print("Hello World")
# Out:
# Hello World

# %%
print(1)
# Out:
# 1

# %%
print(1.1)
# Out:
# 1.1

# %%
print("Hello", 1,1.1,True)
# Out:
# Hello 1 1.1 True

# %%
print("Hello", 1,1.1,True,sep = '/')
# Out:
# Hello/1/1.1/True

# %%
print("Hello", 1,1.1,True, sep = "-")
# Out:
# Hello-1-1.1-True

# %%
print('Hello')
print('World')
# Out:
# Hello
# World

# %%
print("Hello", end = "-")
print("World")
# Out:
# Hello-World

# %% [markdown]
# # Data Types

# %%
#Integer
print(8)
print(1e309)
# Out:
# 8
# inf

# %%
# Decimal/Float
print(8.55)
print(1.7e309)
# Out:
# 8.55
# inf

# %%
# Boolean
print(True)
print(False)
# Out:
# True
# False

# %%
# Text/String
print("Hello World")
# Out:
# Hello World

# %%
# complex
print(5+6j)
# Out:
# (5+6j)

# %%
# List
print([1,2,3,4,5,6])
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# Touple
print((1,2,3,4,5))
# Out:
# (1, 2, 3, 4, 5)

# %%
# Sets
print({1,2,3,5,8,9})
# Out:
# {1, 2, 3, 5, 8, 9}

# %%
# Dictonary
print({"name": "Jitendra","gender":"Male","age": 24})
# Out:
# {'name': 'Jitendra', 'gender': 'Male', 'age': 24}

# %%
# Type
type([1,2,3,4])
# Out:
# list

# %% [markdown]
# # Variables

# %%
name = "jitendra"
print(name)

a = 12
b = 23
print(a+b)
# Out:
# jitendra
# 35

# %%
# Dynamic Typing
a = 5
# Static Typing
int a = 5

# %%
# Dynamic Binding
a = 5
print(a)
a = "name"
print(a)

# static Binding
int a = 5
# Out:
# 5
# name

# %%
a = 1
b = 2
c = 3
print(a,b,c)
# Out:
# 1 2 3

# %%
a, b , c = 1,2,3
print(a,b,c)
# Out:
# 1 2 3

# %%
a = b = c = 5
print(a,b,c)
# Out:
# 5 5 5

# %% [markdown]
# # Comments

# %%
# this is a comment
a = 4
b = 6 # like this
# second comment
print(a+b)
# Out:
# 10

# %% [markdown]
# # Keywords & Identifiers

# %%
# Keywords

# %%
# Identifiers
# You can't start with a digit
name1 = "nitsh"
print(name1)
# You can use special chars - > _
_ = "nitsh"
print(_)
# identifiers can not be keywords
# Out:
# nitsh
# nitsh

# %% [markdown]
# # User Input

# %%
# Static Vs Dynamic
input()
# Out:
# name
# 'name '

# %%
input("Enter mail ")
# Out:
# Enter mail jitendrahere01@gmail.com
# 'jitendrahere01@gmail.com'

# %%
# take input from users and store them in a variable
fnum = input('enter first number')
snum = input('enter second number')
print(type(fnum), type(snum))
# add the 2 variables
result = fnum + snum
# print the result
print(result)
# Out:
# enter first number34
# enter second number56
# <class 'str'> <class 'str'>
# 3456

# %% [markdown]
# # Type Conversion

# %%
# Implicit Vs Explicit

# Implicit
print(5+5.5)
print(type(5),type(5.5))
# Out:
# 10.5
# <class 'int'> <class 'float'>

# %%
print(4 +'4')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2658417670.py in <cell line: 0>()
# ----> 1 print(4 +'4')
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
# Explicit
# str -> int
int('4')
type(int('4'))
# Out:
# int

# %%
int(4+5j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1226094765.py in <cell line: 0>()
# ----> 1 int(4+5j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
# int to str
str(5)
# Out:
# '5'

# %%
# float
float(4)
# Out:
# 4.0

# %%
# take input from users and store them in a variable
fnum = input('enter first number')
snum = input('enter second number')
print(type(fnum), type(snum))
# add the 2 variables
# change type
result = int(fnum) + int(snum)
# print the result
print(result)
# Out:
# enter first number56
# enter second number76
# <class 'str'> <class 'str'>
# 132

# %%
# take input from users and store them in a variable
fnum = int(input('enter first number'))
snum = int(input('enter second number'))
print(type(fnum), type(snum))
# add the 2 variables
# change type
result = int(fnum) + int(snum)
# print the result
print(result)
# Out:
# enter first number56
# enter second number76
# <class 'int'> <class 'int'>
# 132

# %% [markdown]
# # Literals

# %%
a = 0b1010 # Binary literal
print(a)
# Out:
# 10

# %%
#Decimal Literal
b = 100
print(b)
# Out:
# 100

# %%
# Octal Literal
c = 0o310
print(c)
# Out:
# 200

# %%
# Hexadecimal Literal
d = 0x12c
print(d)
# Out:
# 300

# %%
# float Literal
float_1 = 10.5
float_2 = 1.5e2 # 1.5*10^2
float_3 = 1.5e-3
print(float_1,float_2,float_3)
# Out:
# 10.5 150.0 0.0015

# %%
# Complex Literal
x = 3.14j
print(x)
print(x,x.imag,x.real)

y = 5+6j
print(y.imag,y.real)
# Out:
# 3.14j
# 3.14j 3.14 0.0
# 6.0 5.0

# %%
# Boolean Literal
a = True +4
b = False + 10
print(a,b)
print("a:", a)
print("b:", b)
# Out:
# 5 10
# a: 5
# b: 10
